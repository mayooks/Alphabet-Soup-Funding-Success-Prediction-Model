# %% [markdown]
# ## Preprocessing

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/21-Deep-Learning/HomeWork/Resources/charity_data.csv"

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv(path)
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(["EIN", "NAME"], axis = 1, inplace = True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
#are there any null values in the data?
application_df.isnull().sum()
# Out:
# APPLICATION_TYPE          0
# AFFILIATION               0
# CLASSIFICATION            0
# USE_CASE                  0
# ORGANIZATION              0
# STATUS                    0
# INCOME_AMT                0
# SPECIAL_CONSIDERATIONS    0
# ASK_AMT                   0
# IS_SUCCESSFUL             0
# dtype: int64

# %%
#are there any duplicates in the data?
application_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34294     True
# 34295     True
# 34296     True
# 34297     True
# 34298    False
# Length: 34299, dtype: bool

# %%
#application_df.drop_duplicates()

# %%
application_df.head(-100)
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34194               T3  CompanySponsored          C2000  Preservation
# 34195               T3  CompanySponsored          C2000  Preservation
# 34196               T3  CompanySponsored          C2000  Preservation
# 34197               T3       Independent          C2000  Preservation
# 34198               T3  CompanySponsored          C2000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0       Association       1              0                      N     5000
# 1      Co-operative       1         1-9999                      N   108590
# 2       Association       1              0                      N     5000
# 3             Trust       1    10000-24999                      N     6692
# 4             Trust       1  100000-499999                      N   142590
# ...             ...     ...            ...                    ...      ...
# 34194   Association       1              0                      N     5000
# 34195   Association       1              0                      N     5000
# 34196   Association       1              0                      N     5000
# 34197   Association       1              0                      N     5000
# 34198   Association       1              0                      N     5000
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34194              0
# 34195              0
# 34196              0
# 34197              0
# 34198              0
#
# [34199 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
application_df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE

# Replace in dataframe
#for app in application_types_to_replace:
application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(['T9','T13','T12','T2','T25',
                                                                                 'T14','T29','T15','T17'],"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
filtered_classification_df = application_df.groupby('CLASSIFICATION').filter(lambda x : len(x)>1)
filtered_classification_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C4100        6
# C1720        6
# C2400        6
# C1600        5
# C1257        5
# C1260        3
# C2710        3
# C0           3
# C1267        2
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# Name: CLASSIFICATION, dtype: int64

# %%
classfications = filtered_classification_df['CLASSIFICATION'].value_counts().to_frame().reset_index()
classfications.columns = ["classes", "total_counts"]
classfications.head()
# Out:
#   classes  total_counts
# 0   C1000         17326
# 1   C2000          6074
# 2   C1200          4837
# 3   C3000          1918
# 4   C2100          1883

# %%
cut_off_df  = classfications.query("total_counts < 1000")
cut_off_names = cut_off_df.classes.values
classifications = classfications.replace({"classes": {c: "Other" for c in cut_off_names}})

# %%
classifications.head()
# Out:
#   classes  total_counts
# 0   C1000         17326
# 1   C2000          6074
# 2   C1200          4837
# 3   C3000          1918
# 4   C2100          1883

# %%
filtered_classification_df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
target_feature = "IS_SUCCESSFUL"
X = filtered_classification_df.drop(target_feature, axis=1)
y = filtered_classification_df[target_feature]

# %%
X.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 34294    0
# 34295    0
# 34296    0
# 34297    1
# 34298    0
# Name: IS_SUCCESSFUL, Length: 34273, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X = pd.get_dummies(X)

# %%
# Split our preprocessed data into our features and target arrays
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)


# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE

# %%
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (22962, 11311, 22962, 11311)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_train_scaled = scaler.fit_transform(X_train)

# Scale the data
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
X_train_scaled.shape
# Out:
# (22962, 82)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn_model= tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(8, activation="relu", input_shape = (82, )))

# First hidden layer
nn_model.add(tf.keras.layers.Dense(8, activation="relu"))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(8, activation="relu"))




# Output layer
nn_model.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 664
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 8)                 72
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 817
# Trainable params: 817
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
import numpy as np
y_train = np.asarray(y_train).astype('float32').reshape((-1,1))
y_test = np.asarray(y_test).astype('float32').reshape((-1,1))

# %%
# Train the model
nn_model.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 718/718 [==============================] - 4s 3ms/step - loss: 0.6044 - accuracy: 0.6937
# Epoch 2/100
# 718/718 [==============================] - 2s 3ms/step - loss: 0.5671 - accuracy: 0.7235
# Epoch 3/100
# 718/718 [==============================] - 3s 4ms/step - loss: 0.5599 - accuracy: 0.7253
# Epoch 4/100
# 718/718 [==============================] - 3s 5ms/step - loss: 0.5567 - accuracy: 0.7238
# Epoch 5/100
# 718/718 [==============================] - 3s 4ms/step - loss: 0.5542 - accuracy: 0.7264
# Epoch 6/100
# 718/718 [==============================] - 3s 4ms/step - loss: 0.5534 - accuracy: 0.7265
# Epoch 7/100
# 718/718 [==============================] - 3s 5ms/step - loss: 0.5526 - accuracy: 0.7265
# Epoch 8/100
# 718/718 [==============================] - 3s 4ms/step - loss: 0.5520 - accuracy: 0.7262
# Epoch 9/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7266
# Epoch 10/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5512 - accuracy: 0.7262
# Epoch 11/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7276
# Epoch 12/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7270
# Epoch 13/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5497 - accuracy: 0.7273
# Epoch 14/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5493 - accuracy: 0.7277
# Epoch 15/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7286
# Epoch 16/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7287
# Epoch 17/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5480 - accuracy: 0.7286
# Epoch 18/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5480 - accuracy: 0.7273
# Epoch 19/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5476 - accuracy: 0.7271
# Epoch 20/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7293
# Epoch 21/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7295
# Epoch 22/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5468 - accuracy: 0.7288
# Epoch 23/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7275
# Epoch 24/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7286
# Epoch 25/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5464 - accuracy: 0.7293
# Epoch 26/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7292
# Epoch 27/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7311
# Epoch 28/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7315
# Epoch 29/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7309
# Epoch 30/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7309
# Epoch 31/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7296
# Epoch 32/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7305
# Epoch 33/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7310
# Epoch 34/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.7316
# Epoch 35/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7312
# Epoch 36/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5442 - accuracy: 0.7308
# Epoch 37/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7303
# Epoch 38/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7316
# Epoch 39/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7317
# Epoch 40/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7310
# Epoch 41/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7318
# Epoch 42/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7313
# Epoch 43/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7309
# Epoch 44/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7305
# Epoch 45/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7316
# Epoch 46/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5433 - accuracy: 0.7319
# Epoch 47/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7314
# Epoch 48/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7331
# Epoch 49/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7303
# Epoch 50/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7323
# Epoch 51/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7330
# Epoch 52/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7319
# Epoch 53/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7319
# Epoch 54/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7323
# Epoch 55/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7329
# Epoch 56/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7324
# Epoch 57/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7327
# Epoch 58/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7316
# Epoch 59/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7334
# Epoch 60/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7332
# Epoch 61/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7328
# Epoch 62/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7323
# Epoch 63/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7319
# Epoch 64/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7330
# Epoch 65/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7326
# Epoch 66/100
# 718/718 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.7343
# Epoch 67/100
# 718/718 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7329
# Epoch 68/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7315
# Epoch 69/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7323
# Epoch 70/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7321
# Epoch 71/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7322
# Epoch 72/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7342
# Epoch 73/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7322
# Epoch 74/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7337
# Epoch 75/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7327
# Epoch 76/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7331
# Epoch 77/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7341
# Epoch 78/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7329
# Epoch 79/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7326
# Epoch 80/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7330
# Epoch 81/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.7325
# Epoch 82/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7323
# Epoch 83/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7321
# Epoch 84/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7328
# Epoch 85/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7334
# Epoch 86/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7329
# Epoch 87/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5407 - accuracy: 0.7326
# Epoch 88/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7326
# Epoch 89/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7338
# Epoch 90/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.7335
# Epoch 91/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7331
# Epoch 92/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7330
# Epoch 93/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7334
# Epoch 94/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7322
# Epoch 95/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7330
# Epoch 96/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7330
# Epoch 97/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7330
# Epoch 98/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7356
# Epoch 99/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7338
# Epoch 100/100
# 718/718 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7327

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 354/354 - 1s - loss: 0.5470 - accuracy: 0.7355 - 544ms/epoch - 2ms/step
# Loss: 0.5469591617584229, Accuracy: 0.7354787588119507

# %%
# Export our model to HDF5 file
nn_model.save('AlphabetSoupCharity.h5')

# %%
## Model Optimisation

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model2 = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model2.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=90,
        step=5), activation=activation, input_dim=82))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model2.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn_model2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model2.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model2

# %%
pip install keras-tuner --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.7/dist-packages (1.1.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (21.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2022.6.15)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.47.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.2.0)

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
# Import the kerastuner library
import keras_tuner as kt
tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=2)

# %%
y_train
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [0.]], dtype=float32)

# %%
#X_train_scaled = np.asarray(X_train_scaled).astype('float32').reshape((-1,1))

# %%
#X_train_scaled

# %%
#y_train=np.asarray(y_train).astype('float32').reshape((-1,1))

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 508 Complete [00h 04m 23s]
# val_accuracy: 0.7426398992538452
#
# Best val_accuracy So Far: 0.7426398992538452
# Total elapsed time: 03h 44m 50s

# %%
#get parameters for the optimised model
best_hyper = tuner.get_best_hyperparameters()[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 71,
#  'num_layers': 3,
#  'units_0': 5,
#  'units_1': 5,
#  'units_2': 5,
#  'units_3': 9,
#  'units_4': 5,
#  'units_5': 7,
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0230'}

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
# !pwd
# Out:
# /content
